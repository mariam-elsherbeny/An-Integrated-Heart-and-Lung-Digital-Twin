# %%
import tensorflow as tf
import keras 
from keras import layers
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os
from tqdm import tqdm
import re
from keras.preprocessing.image import img_to_array
import warnings
warnings.filterwarnings("ignore")

# %%
# to get the files in proper order
def sorted_alphanumeric(data):  
    convert = lambda text: int(text) if text.isdigit() else text.lower()
    alphanum_key = lambda key: [convert(c) for c in re.split('([0-9]+)',key)]
    return sorted(data,key = alphanum_key)
    # defining the size of the image
SIZE = 128
_img = []
path = '../input/dataset-normal-heart/NormalHeartDataset/'
files = os.listdir(path)
files = sorted_alphanumeric(files)
for i in tqdm(files):    
    if i == 'sample9090.jpg':
        break
    else:
        img = cv2.imread(path + '/'+i,1)
        # open cv reads images in BGR format so we have to convert it to RGB
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        #resizing image
        img = cv2.resize(img, (SIZE, SIZE))
        img = (img - 127.5) / 127.5
        imh = img.astype(float)
        _img.append(img_to_array(img))
# Out:
#  84%|████████▎ | 9088/10855 [01:20<00:15, 113.05it/s]

# %%
def plot_images(sqr = 5):
    plt.figure(figsize = (10,10))
    plt.title("Real Images",fontsize = 35)
    for i in range(sqr * sqr):
       
        ax = plt.subplot(sqr, sqr, i + 1)
        # Ensure the subplot doesn't overlap by specifying a unique position
        ax.clear()  # Clear the axes to prevent overlap issues
        plt.imshow(_img[i] * 0.5 + 0.5)
        plt.xticks([])
        plt.yticks([])
        
        
plt.tight_layout()  # Adjust subplots to fit in figure area.
# to plot images
plot_images(6)

# %%
batch_size = 32
dataset=tf.data.Dataset.from_tensor_slices(np.array(_img)).batch(batch_size)

# %%
latent_dim = 100
def Generator():
    model = tf.keras.Sequential()
    model.add(layers.Input(shape=(latent_dim,)))
    model.add(layers.Dense(128*128*3, use_bias=False, ))
    model.add(layers.Reshape((128,128,3)))
    # downsampling
    model.add(tf.keras.layers.Conv2D(128,4, strides=1, padding='same',kernel_initializer='he_normal', use_bias=False))
    model.add(tf.keras.layers.Conv2D(128,4, strides=2, padding='same',kernel_initializer='he_normal', use_bias=False))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.LeakyReLU())
    model.add(tf.keras.layers.Conv2D(256,4, strides=1, padding='same',kernel_initializer='he_normal', use_bias=False))
    model.add(tf.keras.layers.Conv2D(256,4, strides=2, padding='same',kernel_initializer='he_normal', use_bias=False))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.LeakyReLU())
    model.add(tf.keras.layers.Conv2DTranspose(512, 4, strides=1,padding='same',kernel_initializer='he_normal',use_bias=False))
    model.add(tf.keras.layers.Conv2D(512,4, strides=2, padding='same',kernel_initializer='he_normal', use_bias=False))
    
    model.add(tf.keras.layers.LeakyReLU())
    #upsampling
    model.add(tf.keras.layers.Conv2DTranspose(512, 4, strides=1,padding='same',kernel_initializer='he_normal',use_bias=False))
    model.add(tf.keras.layers.Conv2DTranspose(512, 4, strides=2,padding='same',kernel_initializer='he_normal',use_bias=False))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.LeakyReLU())
    model.add(tf.keras.layers.Conv2DTranspose(256, 4, strides=1,padding='same',kernel_initializer='he_normal',use_bias=False))
    model.add(tf.keras.layers.Conv2DTranspose(256, 4, strides=2,padding='same',kernel_initializer='he_normal',use_bias=False))
    model.add(tf.keras.layers.BatchNormalization())
    
    model.add(tf.keras.layers.Conv2DTranspose(128, 4, strides=2,padding='same',kernel_initializer='he_normal',use_bias=False))
    model.add(tf.keras.layers.Conv2DTranspose(128, 4, strides=1,padding='same',kernel_initializer='he_normal',use_bias=False))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Conv2DTranspose(3,4,strides = 1, padding = 'same',activation = 'tanh'))
    
    

    return model

# %%
generator = Generator()
generator.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 49152)          │     4,915,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 128, 128, 128)  │         6,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 64, 64, 128)    │       262,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 64, 64, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu (LeakyReLU)         │ (None, 64, 64, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 64, 64, 256)    │       524,288 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 32, 32, 256)    │     1,048,576 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 32, 32, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_1 (LeakyReLU)       │ (None, 32, 32, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose                │ (None, 32, 32, 512)    │     2,097,152 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 16, 16, 512)    │     4,194,304 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_2 (LeakyReLU)       │ (None, 16, 16, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_1              │ (None, 16, 16, 512)    │     4,194,304 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_2              │ (None, 32, 32, 512)    │     4,194,304 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 32, 32, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_3 (LeakyReLU)       │ (None, 32, 32, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_3              │ (None, 32, 32, 256)    │     2,097,152 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_4              │ (None, 64, 64, 256)    │     1,048,576 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 64, 64, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_5              │ (None, 128, 128, 128)  │       524,288 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_6              │ (None, 128, 128, 128)  │       262,144 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 128, 128, 128)  │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_7              │ (None, 128, 128, 3)    │         6,147 │
# │ (Conv2DTranspose)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 25,379,843 (96.82 MB)
#  Trainable params: 25,377,283 (96.81 MB)
#  Non-trainable params: 2,560 (10.00 KB)

# %%
def Discriminator():
    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.Input((SIZE, SIZE, 3)))
    model.add(tf.keras.layers.Conv2D(128,4, strides=2, padding='same',kernel_initializer='he_normal', use_bias=False))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.LeakyReLU())
    model.add(tf.keras.layers.Conv2D(128,4, strides=2, padding='same',kernel_initializer='he_normal', use_bias=False))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.LeakyReLU())
    model.add(tf.keras.layers.Conv2D(256,4, strides=2, padding='same',kernel_initializer='he_normal', use_bias=False))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.LeakyReLU())
    model.add(tf.keras.layers.Conv2D(256,4, strides=2, padding='same',kernel_initializer='he_normal', use_bias=False))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.LeakyReLU())
    model.add(tf.keras.layers.Conv2D(512,4, strides=2, padding='same',kernel_initializer='he_normal', use_bias=False))
    model.add(tf.keras.layers.LeakyReLU())
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(1,activation = 'sigmoid'))
    return model

# %%
discriminator = Discriminator()
discriminator.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_5 (Conv2D)               │ (None, 64, 64, 128)    │         6,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 64, 64, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_4 (LeakyReLU)       │ (None, 64, 64, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 32, 32, 128)    │       262,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 32, 32, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_5 (LeakyReLU)       │ (None, 32, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 16, 16, 256)    │       524,288 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 16, 16, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_6 (LeakyReLU)       │ (None, 16, 16, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 8, 8, 256)      │     1,048,576 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 8, 8, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_7 (LeakyReLU)       │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 4, 4, 512)      │     2,097,152 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_8 (LeakyReLU)       │ (None, 4, 4, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 8192)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │         8,193 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,949,569 (15.07 MB)
#  Trainable params: 3,948,033 (15.06 MB)
#  Non-trainable params: 1,536 (6.00 KB)

# %%
noise = np.random.normal(-1,1,(1,100))
img = generator(noise)
plt.imshow(img[0,:,:,0])
plt.show()

# %%
# optimizer = tf.keras.optimizers.RMSprop(
#         learning_rate=0.0001,
#         clipvalue=1.0,
#     )
# lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
#     initial_learning_rate=0.0001,
#     decay_steps=10000,
#     decay_rate=0.96,
#     staircase=True
# )
# optimizer_with_lr_schedule = tf.keras.optimizers.RMSprop(
#     learning_rate=lr_schedule,
#     clipvalue=1.0
# )
cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)

# %%
def generator_loss(fake_output):
    return cross_entropy(tf.ones_like(fake_output), fake_output)

def discriminator_loss(real_output, fake_output):
    real_loss = cross_entropy(tf.ones_like(real_output), real_output)
    fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
    return real_loss + fake_loss

generator_optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.0001, clipvalue=1.0)
discriminator_optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.0001, clipvalue=1.0)

# %%
@tf.function
def train_steps(images):
    noise = tf.random.normal([batch_size, latent_dim])  # Use TensorFlow for noise

    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
        generated_images = generator(noise, training=True)
        fake_output = discriminator(generated_images, training=True)
        real_output = discriminator(images, training=True)

        gen_loss = generator_loss(fake_output)
        dis_loss = discriminator_loss(real_output, fake_output)

    gradients_of_generator = gen_tape.gradient(gen_loss, generator.trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(dis_loss, discriminator.trainable_variables)

    generator_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, discriminator.trainable_variables))

    return {'gen loss': gen_loss, 'disc loss': dis_loss}

# %%
def plot_generated_images(square = 5, epochs = 0):
    
    
  plt.figure(figsize = (10,10))
  for i in range(square * square):
    if epochs != 0:    
        if(i == square //2):
            plt.title("Generated Image at Epoch:{}\n".format(epochs), fontsize = 32, color = 'black')
    plt.subplot(square, square, i+1)
    noise = np.random.normal(0,1,(1,latent_dim))
    img = generator(noise)
    plt.imshow(np.clip((img[0,...]+1)/2, 0, 1))
    
    plt.xticks([])
    plt.yticks([])
    plt.grid()

# %%
import time
def train(epochs, dataset):
    for epoch in range(epochs):
        start = time.time()
        print("\nEpoch : {}".format(epoch + 1))

        for image_batch in dataset:
            loss = train_steps(image_batch)

        print("Time: {}".format(np.round(time.time() - start, 2)))
        print("Generator Loss: {} Discriminator Loss: {}".format(loss['gen loss'], loss['disc loss']))

# %%
train(100,dataset)
# Out:
# Epoch : 1
# Time: 398.69
# Generator Loss: 16.439420700073242 Discriminator Loss: 2.044400025624782e-05
#
# Epoch : 2
# Time: 391.08
# Generator Loss: 7.558111190795898 Discriminator Loss: 0.03481018543243408
#
# Epoch : 3
# Time: 390.38
# Generator Loss: 0.19773328304290771 Discriminator Loss: 2.0093464851379395
#
# Epoch : 4
# Time: 391.16
# Generator Loss: 2.5998075008392334 Discriminator Loss: 1.601595163345337
#
# Epoch : 5
# Time: 391.1
# Generator Loss: 2.5052218437194824 Discriminator Loss: 0.7395105957984924
#
# Epoch : 6
# Time: 391.2
# Generator Loss: 1.7642560005187988 Discriminator Loss: 0.8758067488670349
#
# Epoch : 7
# Time: 390.96
# Generator Loss: 2.5843472480773926 Discriminator Loss: 0.8836013674736023
#
# Epoch : 8
# Time: 390.83
# Generator Loss: 1.9983408451080322 Discriminator Loss: 0.27189821004867554
#
# Epoch : 9
# Time: 390.45
# Generator Loss: 2.718949794769287 Discriminator Loss: 0.7236363291740417
#
# Epoch : 10
# Time: 390.77
# Generator Loss: 1.7909992933273315 Discriminator Loss: 0.31876489520072937
#
# Epoch : 11
# Time: 392.51
# Generator Loss: 2.363758087158203 Discriminator Loss: 0.22308632731437683
#
# Epoch : 12
# Time: 392.45
# Generator Loss: 3.0900678634643555 Discriminator Loss: 0.4719734191894531
#
# Epoch : 13
# Time: 391.96
# Generator Loss: 2.407055616378784 Discriminator Loss: 0.22715970873832703
#
# Epoch : 14
# Time: 390.42
# Generator Loss: 1.5679376125335693 Discriminator Loss: 0.4069082736968994
#
# Epoch : 15
# Time: 390.81
# Generator Loss: 2.737546443939209 Discriminator Loss: 0.2647646963596344
#
# Epoch : 16
# Time: 392.71
# Generator Loss: 2.7792019844055176 Discriminator Loss: 0.24670404195785522
#
# Epoch : 17
# Time: 392.25
# Generator Loss: 3.6969540119171143 Discriminator Loss: 0.42122557759284973
#
# Epoch : 18
# Time: 394.29
# Generator Loss: 3.2487833499908447 Discriminator Loss: 0.21557050943374634
#
# Epoch : 19
# Time: 392.68
# Generator Loss: 3.1735620498657227 Discriminator Loss: 0.29585373401641846
#
# Epoch : 20
# Time: 391.71
# Generator Loss: 3.7134132385253906 Discriminator Loss: 0.22385834157466888
#
# Epoch : 21
# Time: 390.55
# Generator Loss: 2.9994864463806152 Discriminator Loss: 0.20260955393314362
#
# Epoch : 22
# Time: 392.06
# Generator Loss: 4.733719825744629 Discriminator Loss: 0.19561654329299927
#
# Epoch : 23
# Time: 390.52
# Generator Loss: 3.3806116580963135 Discriminator Loss: 0.1123565137386322
#
# Epoch : 24
# Time: 392.5
# Generator Loss: 3.7003092765808105 Discriminator Loss: 0.27965378761291504
#
# Epoch : 25
# Time: 392.11
# Generator Loss: 5.710672378540039 Discriminator Loss: 0.07421731948852539
#
# Epoch : 26
# Time: 391.71
# Generator Loss: 4.218739986419678 Discriminator Loss: 0.15344005823135376
#
# Epoch : 27
# Time: 393.16
# Generator Loss: 3.695952892303467 Discriminator Loss: 0.0648278295993805
#
# Epoch : 28
# Time: 390.26
# Generator Loss: 7.272427558898926 Discriminator Loss: 0.2914729118347168
#
# Epoch : 29
# Time: 392.22
# Generator Loss: 3.671660900115967 Discriminator Loss: 0.08971192687749863
#
# Epoch : 30
# Time: 390.86
# Generator Loss: 21.07145881652832 Discriminator Loss: 4.44205870735459e-05
#
# Epoch : 31
# Time: 390.04
# Generator Loss: 8.644536972045898 Discriminator Loss: 0.00025455147260800004
#
# Epoch : 32
# Time: 390.58
# Generator Loss: 13.953051567077637 Discriminator Loss: 0.131079763174057
#
# Epoch : 33
# Time: 390.58
# Generator Loss: 16.586589813232422 Discriminator Loss: 0.1290217787027359
#
# Epoch : 34
# Time: 390.51
# Generator Loss: 8.555780410766602 Discriminator Loss: 0.03299538418650627
#
# Epoch : 35
# Time: 392.05
# Generator Loss: 3.173367500305176 Discriminator Loss: 0.4614177346229553
#
# Epoch : 36
# Time: 391.95
# Generator Loss: 12.447564125061035 Discriminator Loss: 0.02106407657265663
#
# Epoch : 37
# Time: 391.94
# Generator Loss: 7.98568058013916 Discriminator Loss: 0.03820337727665901
#
# Epoch : 38
# Time: 390.87
# Generator Loss: 29.365962982177734 Discriminator Loss: 0.035344891250133514
#
# Epoch : 39
# Time: 390.72
# Generator Loss: 12.62656307220459 Discriminator Loss: 0.0036815814673900604
#
# Epoch : 40
# Time: 391.04
# Generator Loss: 1.3657221794128418 Discriminator Loss: 0.9729141592979431
#
# Epoch : 41
# Time: 390.85
# Generator Loss: 9.654035568237305 Discriminator Loss: 0.0235152430832386
#
# Epoch : 42
# Time: 390.38
# Generator Loss: 30.821626663208008 Discriminator Loss: 2.7363080978393555
#
# Epoch : 43
# Time: 390.61
# Generator Loss: 16.30976104736328 Discriminator Loss: 0.7406825423240662
#
# Epoch : 44
# Time: 392.44
# Generator Loss: 5.134741306304932 Discriminator Loss: 0.030534345656633377
#
# Epoch : 45
# Time: 392.15
# Generator Loss: 4.960822105407715 Discriminator Loss: 0.009397502057254314
#
# Epoch : 46
# Time: 391.0
# Generator Loss: 6.953244686126709 Discriminator Loss: 0.00411941297352314
#
# Epoch : 47
# Time: 390.06
# Generator Loss: 14.051250457763672 Discriminator Loss: 8.13619262771681e-05
#
# Epoch : 48
# Time: 391.1
# Generator Loss: 13.899076461791992 Discriminator Loss: 6.74743132549338e-05
#
# Epoch : 49
# Time: 390.33
# Generator Loss: 20.402511596679688 Discriminator Loss: 0.1021670326590538
#
# Epoch : 50
# Time: 390.25
# Generator Loss: 24.431060791015625 Discriminator Loss: 0.6353470683097839
#
# Epoch : 51
# Time: 390.58
# Generator Loss: 23.2640323638916 Discriminator Loss: 0.767649233341217
#
# Epoch : 52
# Time: 390.33
# Generator Loss: 7.904699325561523 Discriminator Loss: 0.011252266354858875
#
# Epoch : 53
# Time: 390.3
# Generator Loss: 10.10171127319336 Discriminator Loss: 0.13196952641010284
#
# Epoch : 54
# Time: 390.0
# Generator Loss: 25.536571502685547 Discriminator Loss: 2.43776535987854
#
# Epoch : 55
# Time: 391.97
# Generator Loss: 11.85637378692627 Discriminator Loss: 0.9521688222885132
#
# Epoch : 56
# Time: 390.34
# Generator Loss: 13.556720733642578 Discriminator Loss: 3.398733042558888e-06
#
# Epoch : 57
# Time: 390.84
# Generator Loss: 11.785612106323242 Discriminator Loss: 0.14315059781074524
#
# Epoch : 58
# Time: 390.83
# Generator Loss: 8.937002182006836 Discriminator Loss: 0.7874867916107178
#
# Epoch : 59
# Time: 391.03
# Generator Loss: 8.635232925415039 Discriminator Loss: 0.08375747501850128
#
# Epoch : 60
# Time: 391.02
# Generator Loss: 16.769773483276367 Discriminator Loss: 1.2034664154052734
#
# Epoch : 61
# Time: 389.89
# Generator Loss: 8.182489395141602 Discriminator Loss: 0.059423964470624924
#
# Epoch : 62
# Time: 391.72
# Generator Loss: 28.009902954101562 Discriminator Loss: 2.2189807891845703
#
# Epoch : 63
# Time: 391.4
# Generator Loss: 12.19562816619873 Discriminator Loss: 0.03874665126204491
#
# Epoch : 64
# Time: 390.95
# Generator Loss: 15.381325721740723 Discriminator Loss: 0.20495180785655975
#
# Epoch : 65
# Time: 392.02
# Generator Loss: 15.57184886932373 Discriminator Loss: 0.06863125413656235
#
# Epoch : 66
# Time: 392.73
# Generator Loss: 16.66204261779785 Discriminator Loss: 0.09831655770540237
#
# Epoch : 67
# Time: 391.69
# Generator Loss: 5.190696716308594 Discriminator Loss: 0.05320943146944046
#
# Epoch : 68
# Time: 391.79
# Generator Loss: 15.066829681396484 Discriminator Loss: 0.004607116337865591
#
# Epoch : 69
# Time: 391.5
# Generator Loss: 13.30388069152832 Discriminator Loss: 2.6028876163763925e-05
#
# Epoch : 70
# Time: 391.38
# Generator Loss: 13.680170059204102 Discriminator Loss: 0.0006761035765521228
#
# Epoch : 71
# Time: 391.62
# Generator Loss: 21.160057067871094 Discriminator Loss: 0.07433385401964188
#
# Epoch : 72
# Time: 391.66
# Generator Loss: 31.3953800201416 Discriminator Loss: 3.581723690032959
#
# Epoch : 73
# Time: 392.02
# Generator Loss: 22.017366409301758 Discriminator Loss: 0.43564626574516296
#
# Epoch : 74
# Time: 391.74
# Generator Loss: 23.174301147460938 Discriminator Loss: 0.2157035768032074
#
# Epoch : 75
# Time: 441.9
# Generator Loss: 18.015811920166016 Discriminator Loss: 0.1352553367614746
#
# Epoch : 76
# Time: 392.8
# Generator Loss: 10.623008728027344 Discriminator Loss: 0.007504897192120552
#
# Epoch : 77
# Time: 391.08
# Generator Loss: 23.249618530273438 Discriminator Loss: 1.7606251239776611
#
# Epoch : 78
# Time: 391.81
# Generator Loss: 16.212369918823242 Discriminator Loss: 0.019259700551629066
#
# Epoch : 79
# Time: 391.92
# Generator Loss: 24.647592544555664 Discriminator Loss: 0.08456075936555862
#
# Epoch : 80
# Time: 390.29
# Generator Loss: 10.625986099243164 Discriminator Loss: 0.00013805674097966403
#
# Epoch : 81
# Time: 392.26
# Generator Loss: 19.945837020874023 Discriminator Loss: 2.28118896484375
#
# Epoch : 82
# Time: 391.26
# Generator Loss: 0.9730296730995178 Discriminator Loss: 1.21271812915802
#
# Epoch : 83
# Time: 392.47
# Generator Loss: 5.454545974731445 Discriminator Loss: 0.016725992783904076
#
# Epoch : 84
# Time: 392.32
# Generator Loss: 34.4118537902832 Discriminator Loss: 0.5097256302833557
#
# Epoch : 85
# Time: 392.18
# Generator Loss: 28.428693771362305 Discriminator Loss: 0.6337435841560364
#
# Epoch : 86
# Time: 391.86
# Generator Loss: 5.644575119018555 Discriminator Loss: 0.03439747169613838
#
# Epoch : 87
# Time: 391.22
# Generator Loss: 10.977910995483398 Discriminator Loss: 0.0028723813593387604
#
# Epoch : 88
# Time: 393.04
# Generator Loss: 8.280633926391602 Discriminator Loss: 0.0007158515509217978
#
# Epoch : 89
# Time: 393.78
# Generator Loss: 9.267778396606445 Discriminator Loss: 0.022469565272331238
#
# Epoch : 90
# Time: 391.59
# Generator Loss: 14.572637557983398 Discriminator Loss: 0.26958850026130676
#
# Epoch : 91
# Time: 394.34
# Generator Loss: 13.02159309387207 Discriminator Loss: 0.0008289150428026915
#
# Epoch : 92
# Time: 392.19
# Generator Loss: 9.610282897949219 Discriminator Loss: 0.1930284947156906
#
# Epoch : 93
# Time: 393.86
# Generator Loss: 19.501667022705078 Discriminator Loss: 0.08255717158317566
#
# Epoch : 94
# Time: 393.49
# Generator Loss: 33.950767517089844 Discriminator Loss: 4.935201136646583e-09
#
# Epoch : 95
# Time: 392.55
# Generator Loss: 4.878618240356445 Discriminator Loss: 0.07365550845861435
#
# Epoch : 96
# Time: 392.12
# Generator Loss: 11.39492416381836 Discriminator Loss: 0.1992710679769516
#
# Epoch : 97
# Time: 393.81
# Generator Loss: 28.253273010253906 Discriminator Loss: 2.117779016494751
#
# Epoch : 98
# Time: 392.67
# Generator Loss: 16.927345275878906 Discriminator Loss: 0.013618942350149155
#
# Epoch : 99
# Time: 394.15
# Generator Loss: 11.20417594909668 Discriminator Loss: 0.014760958962142467
#
# Epoch : 100
# Time: 392.29
# Generator Loss: 24.375743865966797 Discriminator Loss: 4.358022124506533e-05

# %%
plot_generated_images(1)

# %%
plot_generated_images(2)

# %%
plot_generated_images(5)

# %%
plot_generated_images(7)

# %%
generator.save('generator.h5')
discriminator.save("discriminator.h5")
